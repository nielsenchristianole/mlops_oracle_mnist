# %%
import cProfile
profiler = cProfile.Profile()
profiler.load_stats('')
profiler.print_stats()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import cProfile
#       2 profiler = cProfile.Profile()
# ----> 3 profiler.load_stats('/Users/oscarbachostdahlpedersen/Documents/5. DTU noter/Kand Semester 1/02476 Machine Learning Operations/mlops_oracle_mnist/reports/profile_output.prof')
#       4 profiler.print_stats()
#
# AttributeError: 'Profile' object has no attribute 'load_stats'

# %%
import pstats

# Load the profile data
stats = pstats.Stats('/Users/oscarbachostdahlpedersen/Documents/5. DTU noter/Kand Semester 1/02476 Machine Learning Operations/mlops_oracle_mnist/reports/profile_output.prof')

# Print the stats (can be sorted by different criteria like time)
stats.strip_dirs().sort_stats('time').print_stats()
# Out:
# Wed Jan 22 14:15:10 2025    /Users/oscarbachostdahlpedersen/Documents/5. DTU noter/Kand Semester 1/02476 Machine Learning Operations/mlops_oracle_mnist/reports/profile_output.prof
#
#          36309659 function calls (33679169 primitive calls) in 399.629 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1362  178.182    0.131  178.182    0.131 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     95347   75.286    0.001   75.287    0.001 {built-in method torch.conv2d}
#    193404   11.746    0.000   11.746    0.000 {method 'lerp_' of 'torch._C.TensorBase' objects}
#     61166   10.370    0.000   10.371    0.000 {built-in method torch.batch_norm}
#   167/164    7.632    0.046    7.925    0.048 {built-in method _imp.create_dynamic}
#      1362    7.567    0.006   35.558    0.026 adam.py:320(_single_tensor_adam)
#     34181    4.435    0.000    4.435    0.000 {built-in method torch._C._nn.hardswish_}
# ...
